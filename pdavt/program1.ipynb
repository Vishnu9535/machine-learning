# %%
import numpy as np
arr = np.array([[1,2,3],[5,6,7]])
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr.ndim)
print(arr.size)
print(type(arr))
print(arr.dtype)
# Out:
# 2
# 6
# <class 'numpy.ndarray'>
# int32

# %%
a = np.array([[1,2,3,4],[5,6,6,8],[9,1,3,4]])
print(a)
print(a[:,2:3])
# Out:
# [[1 2 3 4]
#  [5 6 6 8]
#  [9 1 3 4]]
# [[3]
#  [6]
#  [3]]

# %%
import pandas as pd
x = np.array([['jjsv','col1','col2','col3'],['row1',1,2,3],['row2',2,3,4],['row3',5,6,7]])
print(pd.DataFrame(data=x[1:,1:],index=x[1:,0],columns= x[0,1:]))
# Out:
#      col1 col2 col3
# row1    1    2    3
# row2    2    3    4
# row3    5    6    7

# %%
arr_2d =  np.array([[1,2,3],[4,5,6]])
# print(pd.DataFrame(arr_2d))
my_dict = {1: ['1', '3'], 2: ['1', '2'], 3: ['2', '4']}
print(pd.DataFrame(my_dict))
# Out:
#    1  2  3
# 0  1  1  2
# 1  3  2  4

# %%
my_df = pd.DataFrame(data = [[4,5,6],[6,7,8]], index=range(0,2),columns=['A','B','C'])

print(pd.DataFrame(my_df))
# Out:
#    A  B  C
# 0  4  5  6
# 1  6  7  8

# %%
my_series= pd.Series({"United kingdom":"london","india":"newdelhi","united states ":"wasington"})
print(pd.DataFrame(my_series))
df = pd.DataFrame(np.array([[1, 2, 3], [4, 5, 6]]))
print(df.shape)
print(df.size)
# Out:
#                         0
# United kingdom     london
# india            newdelhi
# united states   wasington
# (2, 3)
# 6

# %%
import matplotlib.pyplot as plt 
x= [5,4,3,2,1]

y =[3,10,8,6,2]
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y - axixs')
plt.title('my firsty one ')
plt.show()

# %%
import matplotlib.pyplot as plt

a= [1,2,3,4,5]
b = [4,5,6,7,8,9,10,2,3]
plt.plot(a)
plt.plot(b,"or")
plt.plot(list(range(0,20,2)))
plt.xlabel('x axis')
plt.ylabel('yaxis')
c=[1,2,3,4,5,6,7,8]
plt.plot(c,label='4th rep')
plt.legend(['1st Rep', '2nd Rep', '3rd Rep', '4th Rep'])
# plt.spines['right'].set_visible(False)
# plt.spines['top'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
a = [1, 2, 3, 4, 5]
b = [0, 0.6, 0.2, 15, 10, 8, 16, 21]
c = [4, 2, 6, 8, 3, 20, 13, 15]

# Plotting
plt.plot(a, label='1st Rep')
plt.plot(b, 'or', label='2nd Rep')
plt.plot(range(0, 22, 3), label='3rd Rep')
plt.plot(c, label='4th Rep')

# Styling
plt.xlabel('Day ->')
plt.ylabel('Temp ->')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_bounds(-3, 40)
plt.xticks(list(range(-3, 10)))
plt.yticks(list(range(-3, 20, 3)))
plt.legend(['1st Rep', '2nd Rep', '3rd Rep', '4th Rep'])

# Annotation
plt.annotate('Temperature V / s Days', xy=(1.01, -2.15))

# Title
plt.title('All Features Discussed')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5,6,7]
b = [2,4,6,7,9,8]
c= [1,4,6,8,9,10,12]

# fig = plt.figure(figsize=(10,10))
sub1 = plt.subplot(2,2,1)
sub2 = plt.subplot(2,2,2)
sub3 = plt.subplot(2,2,3)
sub4 = plt.subplot(2,2,4)
sub1.plot(a,'sb')
sub2.plot(b,'or')
sub3.plot(list(range(1,22,2)),'vg')
sub4.plot(c,'dm')
plt.show()

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import gutenberg
import nltk
nltk.download('gutenberg')
sample = gutenberg.raw('blake-poem.txt')
token = word_tokenize(sample)
wlist =[]
for w in token:
    wlist.append(w)

wfreq= [wlist.count(i) for i in wlist]
print(str(zip(token,wfreq)))
# Out:
# [nltk_data] Error loading gutenberg: <urlopen error [WinError 10054]
# [nltk_data]     An existing connection was forcibly closed by the
# [nltk_data]     remote host>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource gutenberg not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('gutenberg')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/gutenberg.zip/gutenberg/
#
#   Searched in:
#     - 'C:\\Users\\vishn/nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\share\\nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\vishn\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# c:\Users\vishn\OneDrive\Documents\meachine-learning\pdavt\program1.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program1.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> import nltk
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program1.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> nltk.download('gutenberg')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program1.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> sample = gutenberg.raw('blake-poem.txt')
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program1.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> token = word_tokenize(sample)
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program1.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> wlist =[]
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource gutenberg not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('gutenberg')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/gutenberg
#
#   Searched in:
#     - 'C:\\Users\\vishn/nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\share\\nltk_data'
#     - 'c:\\Users\\vishn\\AppData\\Local\\Programs\\Python\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\vishn\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
import numpy as np

# Example usage
values = np.array([4, 5, 6])
weights = np.array([0.2, 0.3, 0.5])

result = np.average(values, weights=weights)
print(f"Weighted Average: {result}")
# Out:
# Weighted Average: 5.3

# %%
from statistics import variance
from fractions import Fraction as fr
sample = (1,-1,2,3,4,5,8,-3,10)
print(variance(sample))
# Out:
# 16.944444444444443

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sub
data = np.arange(1,10,0.01)
cur = norm.pdf(data,loc=5.3,scale =1)
plt.plot(data,cur)
plt.show()

# %%
import   numpy as np
import matplotlib.pyplot as plt
x= np.random.randn(80)
y1 = x*5+5
y2=x*9+8
y3=x*8+2
cor1 = np.corrcoef(x,y1)[0,1]
cor2 = np.corrcoef(x,y2)[0,1]
cor3 = np.corrcoef(x,y3)[0,1]
plt.scatter(x,y1,label=f"corelation ={cor1:.2f}")
plt.scatter(x,y2,label=f"corelation ={cor2:.2f}")
plt.scatter(x,y3,label=f"corelation ={cor3:.2f}")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simple_linear_regression(x, y):
    # Calculate the slope (m) and y-intercept (b) of the regression line
    m = np.cov(x, y)[0, 1] / np.var(x)
    b = np.mean(y) - m * np.mean(x)
    return m, b

def predict(x, m, b):
    # Predict the y values using the regression equation
    return m * x + b

# Generate sample data
np.random.seed(0)
x = np.random.rand(50) * 10
y = 2 * x + 1 + np.random.randn(50) * 2  # y = 2x + 1 + noise

# Perform simple linear regression
slope, intercept = simple_linear_regression(x, y)

# Make predictions using the regression equation
y_pred = predict(x, slope, intercept)

# Plot the data points and regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label=f'Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Labeling the plot
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.legend()

# Show the plot
plt.show()
