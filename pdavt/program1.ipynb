# %%
#1  
import numpy as np
arr = np.array([[1,2,3],[5,6,7]])
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr.ndim)
print(arr.size)
print(type(arr))
print(arr.dtype)
# Out:
# 2
# 6
# <class 'numpy.ndarray'>
# int32

# %%
a = np.array([[1,2,3,4],[5,6,6,8],[9,1,3,4]])


print(a)
print(a[:,1:3])
print(a[:,:2])
# Out:
# [[1 2 3 4]
#  [5 6 6 8]
#  [9 1 3 4]]
# [[2 3]
#  [6 6]
#  [1 3]]
# [[1 2]
#  [5 6]
#  [9 1]]

# %%
#2
import numpy as np
import pandas as pd
x = np.array([['jjsv','col1','col2','col3'],['row1',1,2,3],['row2',2,3,4],['row3',5,6,7]])
print(pd.DataFrame(data=x[1:,1:],index=x[1:,0],columns= x[0,1:]))
# Out:
#      col1 col2 col3
# row1    1    2    3
# row2    2    3    4
# row3    5    6    7

# %%
arr_2d =  np.array([[1,2,3],[4,5,6]])
# print(pd.DataFrame(arr_2d))
my_dict = {1: ['1', '3'], 2: ['1', '2'], 3: ['2', '4']}
print(pd.DataFrame(my_dict))
# Out:
#    1  2  3
# 0  1  1  2
# 1  3  2  4

# %%
my_df = pd.DataFrame(data = [[4,5,6],[6,7,8]], index=range(0,2),columns=['A','B','C'])

print(pd.DataFrame(my_df))
# Out:
#    A  B  C
# 0  4  5  6
# 1  6  7  8

# %%
my_series= pd.Series({"United kingdom":"london","india":"newdelhi","united states ":"wasington"})
print(pd.DataFrame(my_series))
df = pd.DataFrame(np.array([[1, 2, 3], [4, 5, 6]]))
print(df.shape)
print(df.size)
print(len(df.index))
# Out:
#                         0
# United kingdom     london
# india            newdelhi
# united states   wasington
# (2, 3)
# 6
# 2

# %%
#3a
import matplotlib.pyplot as plt 
x= [5,4,3,2,1]

y =[3,10,8,6,2]
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y - axixs')
plt.title('my firsty one ')
plt.show()

# %%
#3b
import matplotlib.pyplot as plt

a= [1,2,3,4,5]
b = [4,5,6,7,8,9,10,2,3]
plt.plot(a)
plt.plot(b,"or")
plt.plot(list(range(0,20,2)))
plt.xlabel('x axis')
plt.ylabel('yaxis')
c=[1,2,3,4,5,6,7,8]
plt.plot(c,label='4th rep')
plt.legend(['1st Rep', '2nd Rep', '3rd Rep', '4th Rep'])
# plt.spines['right'].set_visible(False)
# plt.spines['top'].set_visible(False)

plt.show()

# %%
#3c
import matplotlib.pyplot as plt

# Data
a = [1, 2, 3, 4, 5]
b = [0, 0.6, 0.2, 15, 10, 8, 16, 21]
c = [4, 2, 6, 8, 3, 20, 13, 15]

# Plotting
plt.plot(a, label='1st Rep')
plt.plot(b, 'or', label='2nd Rep')
plt.plot(range(0, 22, 3), label='3rd Rep')
plt.plot(c, label='4th Rep')

# Styling
plt.xlabel('Day ->')
plt.ylabel('Temp ->')
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['left'].set_bounds(-3, 40)
plt.xticks(list(range(-3, 10)))
plt.yticks(list(range(-3, 20, 3)))
plt.legend()

# Annotation
plt.annotate('Temperature V / s Days', xy=(1.01, -2.15))

# Title
plt.title('All Features Discussed')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5,6,7]
b = [2,4,6,7,9,8]
c= [1,4,6,8,9,10,12]

fig = plt.figure(figsize=(10,10))
sub1 = plt.subplot(2,2,1)
sub2 = plt.subplot(2,2,2)
sub3 = plt.subplot(2,2,3)
sub4 = plt.subplot(2,2,4)
sub1.plot(a,'sb')
sub2.plot(b,'or')
sub3.plot(list(range(1,22,2)),'vg')
sub4.plot(c,'dm')
plt.show()

# %%
import nltk
# nltk.download('punkt')
nltk.download('all')
# nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\vishn\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# ...

# %%
#4
from nltk.tokenize import word_tokenize
from nltk.corpus import gutenberg
from collections import Counter

sample = gutenberg.raw('blake-poems.txt')
tokens = word_tokenize(sample)

# Remove non-alphabetic tokens
tokens = [word.lower() for word in tokens if word.isalpha()]

# Count word frequencies using Counter
word_freq = Counter(tokens)

# Print the word frequencies
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# poems: 1
# by: 24
# william: 2
# blake: 4
# songs: 7
# of: 146
# innocence: 3
# and: 348
# experience: 3
# the: 439
# book: 6
# thel: 16
# introduction: 2
# piping: 3
# down: 20
# valleys: 4
# wild: 9
# pleasant: 5
# glee: 1
# on: 44
# a: 127
# cloud: 15
# i: 130
# saw: 7
# child: 18
# he: 56
# laughing: 5
# said: 8
# to: 111
# me: 34
# pipe: 4
# song: 10
# about: 1
# lamb: 15
# so: 21
# piped: 2
# with: 66
# merry: 9
# cheer: 2
# piper: 2
# that: 39
# again: 3
# wept: 9
# hear: 16
# drop: 1
# thy: 31
# happy: 19
# sing: 11
# sang: 2
# same: 1
# while: 14
# joy: 25
# sit: 12
# thee: 42
# write: 1
# in: 141
# all: 39
# may: 6
# read: 2
# vanish: 4
# from: 32
# my: 83
# sight: 2
# pluck: 1
# hollow: 3
# reed: 1
# made: 6
# rural: 1
# pen: 1
# stain: 2
# water: 3
# clear: 1
# wrote: 1
# every: 17
# shepherd: 3
# how: 14
# sweet: 28
# is: 52
# lot: 2
# morn: 8
# evening: 5
# stays: 1
# shall: 19
# follow: 3
# his: 57
# sheep: 4
# day: 19
# tongue: 4
# be: 25
# filled: 6
# praise: 2
# ...

# %%
#5
import numpy as np

# Example usage
values = np.array([4, 5, 6])
weights = np.array([0.2, 0.3, 0.5])

result = np.average(values, weights=weights)
print(f"Weighted Average: {result}")
# Out:
# Weighted Average: 5.3

# %%
#6
from statistics import variance
from fractions import Fraction as fr
sample = (1,-1,2,3,4,5,8,-3,10)
s4=(fr(1,2),fr(2,3),fr(3,4),fr(5,6),fr(7,8))
print(variance(s4))
print(variance(sample))
# Out:
# 1/45
# 16.944444444444443

# %%
#7

from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sub
data = np.arange(1,10,0.01)
cur = norm.pdf(data,loc=5.3,scale =1)
plt.plot(data,cur)
plt.show()

# %%
#8
import   numpy as np
import matplotlib.pyplot as plt
x= np.random.randn(80)
y1 = x*5+5
y2=x*9+8
y3=x*8+2
cor1 = np.corrcoef(x,y1)[0,1]
cor2 = np.corrcoef(x,y2)[0,1]
cor3 = np.corrcoef(x,y3)[0,1]
plt.scatter(x,y1,label=f"corelation ={cor1:.2f}")
plt.scatter(x,y2,label=f"corelation ={cor2:.2f}")
plt.scatter(x,y3,label=f"corelation ={cor3:.2f}")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def simple_linear_regression(x, y):
    # Calculate the slope (m) and y-intercept (b) of the regression line
    m = np.cov(x, y)[0, 1] / np.var(x)
    b = np.mean(y) - m * np.mean(x)
    return m, b

def predict(x, m, b):
    # Predict the y values using the regression equation
    return m * x + b

# Generate sample data
np.random.seed(0)
x = np.random.rand(50) * 10
y = 2 * x + 1 + np.random.randn(50) * 2  # y = 2x + 1 + noise

# Perform simple linear regression
slope, intercept = simple_linear_regression(x, y)

# Make predictions using the regression equation
y_pred = predict(x, slope, intercept)

# Plot the data points and regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label=f'Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Labeling the plot
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.legend()

# Show the plot
plt.show()
