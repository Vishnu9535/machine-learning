# %%
import numpy as np
import pandas as pd 

con = pd.read_csv('concrete.csv')
list(con.columns)
# Out:
# ['cement',
#  'slag',
#  'ash',
#  'water',
#  'superplastic',
#  'coarseagg',
#  'fineagg',
#  'age',
#  'strength']

# %%
import seaborn as sns
# sns.scatter

# %%
sns.scatterplot(x="ash", y="strength", data=con);

# %%
ax = sns.scatterplot(x="ash", y="strength", data=con)
ax.set_title("Concrete Strength vs. Fly ash")
ax.set_xlabel("Fly ash")
# Out:
# Text(0.5, 0, 'Fly ash')

# %%
sns.lmplot(x="ash", y="strength", data=con)

# %%
from scipy import stats
stats.pearsonr(con['strength'], con['ash'])
    
PearsonResult(statistic=-0.10575491629731354, pvalue=0.0006751583555753)

cormat = con.corr()
round(cormat,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\vishn\OneDrive\Documents\meachine-learning\pdavt\program9.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program9.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from scipy import stats
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program9.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> stats.pearsonr(con['strength'], con['ash'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program9.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> PearsonRResult(statistic=-0.10575491629731354, pvalue=0.0006751583555753)
#       <a href='vscode-notebook-cell:/c%3A/Users/vishn/OneDrive/Documents/meachine-learning/pdavt/program9.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> cormat = con.corr()
# ...
